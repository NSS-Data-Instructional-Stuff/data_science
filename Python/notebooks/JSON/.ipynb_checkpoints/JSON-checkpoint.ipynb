# %% [markdown]
# ## Working with JSON
#
# **J**ava**S**cript **O**bject **N**otation
#
# Uses human-readable text in a form that looks like a Python dictionary or list of dictionaries (or dictionaries of lists containing dictionaries, etc.)
#
# A very popular way to serialize data, especially in web development.
#
# ```python
# {
#     "firstName": "Jane",
#     "lastName": "Doe",
#     "hobbies": ["running", "sky diving", "singing"],
#     "age": 35,
#     "children": [
#         {
#             "firstName": "Alice",
#             "age": 6
#         },
#         {
#             "firstName": "Bob",
#             "age": 8
#         }
#     ]
# }```
#
# See [this](https://www.youtube.com/watch?v=A0hoqSkyY7o) _Computerphile_ video for more information about JSON.
#
# You can interact with json files in Python using the json library.

# %%
import json

# %% [markdown]
# We've got a json file that we would like to import. We can do this using the `json.load()` function. We need to passing in a "file-like object" containing our JSON document. This can be created using a context manager. Basically, this will allow us to open the file, read what we need from it, but then will close the file when we're done.

# %%
with open('data/example.json', "r") as fi:
    person = json.load(fi)

# %%
person
# Out:
# {'firstName': 'Jane',
#  'lastName': 'Doe',
#  'hobbies': ['running', 'sky diving', 'singing'],
#  'age': 35,
#  'children': [{'firstName': 'Alice', 'age': 6},
#   {'firstName': 'Bob', 'age': 8}]}

# %%
type(person)
# Out:
# dict

# %% [markdown]
# Quite often, APIs will return results formatted as JSON. For example, let's fetch the Metro Nashville traffic accidents.

# %%
import requests
import pandas as pd

# %%
url = 'https://data.nashville.gov/resource/6v6w-hpcw.json'

response = requests.get(url)

# %% [markdown]
# We can view the response in "JSON form", which is a list of (nested) dictionaries.

# %%
response.json()
# Out:
# [{'accident_number': 'VU 130097461',
#   'date_and_time': '2013-08-13T00:00:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '494',
#   'collision_type': '3',
#   'weather': '1',
#   'weather_description': 'NO ADVERSE CONDITIONS',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12;14',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT;PARKED MOTOR VEHICLE',
#   'street_address': 'POWELL AVE',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37204',
#   'rpa': '8525',
#   'precinct': 'MIDTOW',
#   'lat': '36.1099',
#   'long': '-86.7644',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7644, 36.1099]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '9',
#   ':@computed_region_gxvr_9jxz': '25'},
#  {'accident_number': '20400639785',
#   'date_and_time': '2014-07-06T12:45:00.000',
#   'number_of_motor_vehicles': '2.0000',
#   'number_of_injuries': '0.0000',
#   'number_of_fatalities': '0.0000',
#   'hit_and_run': False,
#   'reporting_officer': '473187',
#   'collision_type': '5',
#   'collision_type_description': 'SIDESWIPE - SAME DIRECTION',
#   'weather': '21',
#   'weather_description': 'CLEAR',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MM 93 0 I65 N',
#   'city': 'MADISON',
#   'state': 'TN',
#   'zip': '37115',
#   'rpa': '17040',
#   'precinct': 'MADISO',
#   'lat': '0.0000',
#   'long': '0.0000',
#   'mapped_location': {'type': 'Point', 'coordinates': [0, 0]}},
#  {'accident_number': '20200677519',
#   'date_and_time': '2020-10-28T19:35:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '352172',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'HARDING PKE & RIDGEFIELD WAY',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37205',
#   'rpa': '6021',
#   'precinct': 'WEST',
#   'lat': '36.1264',
#   'long': '-86.8456',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8456, 36.1264]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '10',
#   ':@computed_region_gxvr_9jxz': '5'},
#  {'accident_number': '20200677514',
#   'date_and_time': '2020-10-28T21:15:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '4001081',
#   'collision_type': '5',
#   'collision_type_description': 'SIDESWIPE - SAME DIRECTION',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MM 90 6 I 65',
#   'city': 'MADISON',
#   'state': 'TN',
#   'zip': '37115',
#   'rpa': '17020',
#   'precinct': 'MADISO',
#   'lat': '36.2435',
#   'long': '-86.7481',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7481, 36.2435]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '3',
#   ':@computed_region_gxvr_9jxz': '12'},
#  {'accident_number': '20200677469',
#   'date_and_time': '2020-10-28T20:30:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '320586',
#   'collision_type': '6',
#   'collision_type_description': 'SIDESWIPE - OPPOSITE DIRECTION',
#   'illuaccidemination': '2',
#   'illumination_description': 'DARK - NOT LIGHTED',
#   'harmfulcodes': '14',
#   'harmfuldescriptions': 'PARKED MOTOR VEHICLE',
#   'street_address': 'GUILL CT & RIVERSTONE BLVD',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37214',
#   'rpa': '9311',
#   'precinct': 'HERMIT',
#   'lat': '36.1713',
#   'long': '-86.6555',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6555, 36.1713]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '7',
#   ':@computed_region_gxvr_9jxz': '38'},
#  {'accident_number': '20200677467',
#   'date_and_time': '2020-10-28T20:42:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '197047',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '31',
#   'harmfuldescriptions': 'OTHER POST, POLE, SUPP.',
#   'street_address': 'S 4TH ST & RUSSELL ST',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37206',
#   'rpa': '1111',
#   'precinct': 'EAST',
#   'lat': '36.1703',
#   'long': '-86.7655',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7655, 36.1703]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '14',
#   ':@computed_region_gxvr_9jxz': '4'},
#  {'accident_number': '20200677452',
#   'date_and_time': '2020-10-28T20:18:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '256386',
#   'collision_type': '5',
#   'collision_type_description': 'SIDESWIPE - SAME DIRECTION',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'OLD HICKORY BLVD & NOLENSVILLE PKE',
#   'city': 'ANTIOCH',
#   'state': 'TN',
#   'zip': '37013',
#   'rpa': '8757',
#   'precinct': 'SOUTH',
#   'lat': '36.0455',
#   'long': '-86.7122',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7122, 36.0455]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '21',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'accident_number': '20200677439',
#   'date_and_time': '2020-10-28T19:20:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '4000723',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '2',
#   'illumination_description': 'DARK - NOT LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': '0 I440 W EXT RAMP',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37212',
#   'rpa': '5905',
#   'precinct': 'MIDTOW',
#   'lat': '36.1364',
#   'long': '-86.8203',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8203, 36.1364]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '19',
#   ':@computed_region_gxvr_9jxz': '36'},
#  {'accident_number': '20200677413',
#   'date_and_time': '2020-10-28T19:15:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '429193',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'illuaccidemination': '2',
#   'illumination_description': 'DARK - NOT LIGHTED',
#   'harmfulcodes': '34',
#   'harmfuldescriptions': 'DITCH',
#   'street_address': 'RIVER ROAD PKE & INDIAN CREEK RD',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37209',
#   'rpa': '4707',
#   'precinct': 'WEST',
#   'lat': '36.1387',
#   'long': '-86.9512',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.9512, 36.1387]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '35',
#   ':@computed_region_gxvr_9jxz': '46'},
#  {'accident_number': '20200677390',
#   'date_and_time': '2020-10-28T17:30:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '163667',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'SIDCO DR & HARDING PL',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37204',
#   'rpa': '8531',
#   'precinct': 'MIDTOW',
#   'lat': '36.0834',
#   'long': '-86.7616',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7616, 36.0834]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '9',
#   ':@computed_region_gxvr_9jxz': '25'},
#  {'accident_number': '20200677350',
#   'date_and_time': '2020-10-28T18:57:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '384436',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'HARDING PL & LARGO DR',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37211',
#   'rpa': '8705',
#   'precinct': 'SOUTH',
#   'lat': '36.0833',
#   'long': '-86.7086',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7086, 36.0833]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '12',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'accident_number': '20200677317',
#   'date_and_time': '2020-10-28T18:35:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '4001446',
#   'collision_type': '5',
#   'collision_type_description': 'SIDESWIPE - SAME DIRECTION',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'WEDGEWOOD AV & 12TH AVS',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37203',
#   'rpa': '6913',
#   'precinct': 'MIDTOW',
#   'lat': '36.1361',
#   'long': '-86.7879',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7879, 36.1361]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '18',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'accident_number': '20200677313',
#   'date_and_time': '2020-10-28T17:41:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '352186',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '5',
#   'illumination_description': 'DUSK',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MM 58 2 I 24',
#   'city': 'ANTIOCH',
#   'state': 'TN',
#   'zip': '37013',
#   'rpa': '87060',
#   'precinct': 'SOUTH',
#   'lat': '36.0564',
#   'long': '-86.6761',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6761, 36.0564]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '28',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'accident_number': '20200677299',
#   'date_and_time': '2020-10-28T17:20:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '256383',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MURFREESBORO PKE & BRITISH WOODS DR',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37217',
#   'rpa': '8853',
#   'precinct': 'SOUTH',
#   'lat': '36.0914',
#   'long': '-86.6514',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6514, 36.0914]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '22',
#   ':@computed_region_gxvr_9jxz': '22'},
#  {'accident_number': '20200677292',
#   'date_and_time': '2020-10-28T18:52:00.000',
#   'number_of_motor_vehicles': '3',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '330431',
#   'collision_type': '5',
#   'collision_type_description': 'SIDESWIPE - SAME DIRECTION',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MM 213 0 I 40',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37210',
#   'rpa': '8219',
#   'precinct': 'HERMIT',
#   'lat': '36.1407',
#   'long': '-86.7323',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7323, 36.1407]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '11'},
#  {'accident_number': '20200677270',
#   'date_and_time': '2020-10-28T17:20:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '4000723',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': '2500 CHARLOTTE AV',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37209',
#   'rpa': '5339',
#   'precinct': 'NORTH',
#   'lat': '36.1553',
#   'long': '-86.8121',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8121, 36.1553]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '25',
#   ':@computed_region_gxvr_9jxz': '40'},
#  {'accident_number': '20200677262',
#   'date_and_time': '2020-10-28T18:25:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '2',
#   'number_of_fatalities': '0',
#   'property_damage': True,
#   'hit_and_run': False,
#   'reporting_officer': '4000823',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '2',
#   'illumination_description': 'DARK - NOT LIGHTED',
#   'harmfulcodes': '12;24;36',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT;GUARDRAIL FACE;CONCRETE TRAFFIC BARRIER',
#   'street_address': 'MM 200 6 I 40',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37209',
#   'rpa': '4708',
#   'precinct': 'WEST',
#   'lat': '36.1261',
#   'long': '-86.904',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.904, 36.1261]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '32',
#   ':@computed_region_gxvr_9jxz': '5'},
#  {'accident_number': '20200677255',
#   'date_and_time': '2020-10-28T16:39:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '279233',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'LEALAND LN & BATTERY LN',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37220',
#   'rpa': '7105',
#   'precinct': 'MIDTOW',
#   'lat': '36.0883',
#   'long': '-86.791',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.791, 36.0883]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '11',
#   ':@computed_region_gxvr_9jxz': '27'},
#  {'accident_number': '20200677234',
#   'date_and_time': '2020-10-28T17:55:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '409191',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'OLD HICKORY BLVDW & DICKERSON PKE',
#   'city': 'MADISON',
#   'state': 'TN',
#   'zip': '37115',
#   'rpa': '2039',
#   'precinct': 'MADISO',
#   'lat': '36.2692',
#   'long': '-86.7556',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7556, 36.2692]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '3',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'accident_number': '20200677205',
#   'date_and_time': '2020-10-28T17:38:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '151132',
#   'collision_type': '5',
#   'collision_type_description': 'SIDESWIPE - SAME DIRECTION',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MM 40 4 I 24',
#   'city': 'WHITES CREEK',
#   'state': 'TN',
#   'zip': '37189',
#   'rpa': '3314',
#   'precinct': 'NORTH',
#   'lat': '36.2786',
#   'long': '-86.8016',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8016, 36.2786]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '16',
#   ':@computed_region_gxvr_9jxz': '6'},
#  {'accident_number': '20200677203',
#   'date_and_time': '2020-10-28T17:03:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '320599',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '5',
#   'illumination_description': 'DUSK',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'US HWY 41 & RAMP',
#   'city': 'ANTIOCH',
#   'state': 'TN',
#   'zip': '37013',
#   'rpa': '8979',
#   'precinct': 'SOUTH',
#   'lat': '36.0704',
#   'long': '-86.6345',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6345, 36.0704]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '23',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'accident_number': '20200677188',
#   'date_and_time': '2020-10-28T17:30:00.000',
#   'number_of_motor_vehicles': '4',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '320592',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MM 90 1 I 65',
#   'city': 'MADISON',
#   'state': 'TN',
#   'zip': '37115',
#   'rpa': '20022',
#   'precinct': 'MADISO',
#   'lat': '36.239',
#   'long': '-86.7548',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7548, 36.239]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '3',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'accident_number': '20200677186',
#   'date_and_time': '2020-10-28T17:27:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '352172',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '36',
#   'harmfuldescriptions': 'CONCRETE TRAFFIC BARRIER',
#   'street_address': 'MM 203 5 I 40',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37209',
#   'rpa': '46020',
#   'precinct': 'WEST',
#   'lat': '36.1509',
#   'long': '-86.8647',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8647, 36.1509]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '24',
#   ':@computed_region_gxvr_9jxz': '46'},
#  {'accident_number': '20200677170',
#   'date_and_time': '2020-10-28T17:12:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '4001446',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '36',
#   'harmfuldescriptions': 'CONCRETE TRAFFIC BARRIER',
#   'street_address': 'MM 3 4 I 440',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37212',
#   'rpa': '6502',
#   'precinct': 'MIDTOW',
#   'lat': '36.1162',
#   'long': '-86.7974',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7974, 36.1162]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '19',
#   ':@computed_region_gxvr_9jxz': '47'},
#  {'accident_number': '20200677154',
#   'date_and_time': '2020-10-28T17:00:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '256414',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': '51ST AVN & LOUISIANA AV',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37209',
#   'rpa': '4607',
#   'precinct': 'WEST',
#   'lat': '36.162',
#   'long': '-86.8491',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8491, 36.162]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '24',
#   ':@computed_region_gxvr_9jxz': '46'},
#  {'accident_number': '20200677131',
#   'date_and_time': '2020-10-28T16:50:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '429193',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '5',
#   'illumination_description': 'DUSK',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'CHARLOTTE PKE & I40 E ENT RAMP',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37205',
#   'rpa': '5007',
#   'precinct': 'WEST',
#   'lat': '36.1319',
#   'long': '-86.8955',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8955, 36.1319]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '24',
#   ':@computed_region_gxvr_9jxz': '46'},
#  {'accident_number': '20200677128',
#   'date_and_time': '2020-10-28T16:59:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '311333',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '36',
#   'harmfuldescriptions': 'CONCRETE TRAFFIC BARRIER',
#   'street_address': 'STATE HWY 155 & CREEKBEND DR',
#   'city': 'WHITES CREEK',
#   'state': 'TN',
#   'zip': '37189',
#   'rpa': '3202',
#   'precinct': 'NORTH',
#   'lat': '36.2353',
#   'long': '-86.7986',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7986, 36.2353]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '16',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'accident_number': '20200677126',
#   'date_and_time': '2020-10-28T00:00:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '279233',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'FRANKLIN PKE & HARDING PL',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37204',
#   'rpa': '7027',
#   'precinct': 'MIDTOW',
#   'lat': '36.0866',
#   'long': '-86.772',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.772, 36.0866]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '11',
#   ':@computed_region_gxvr_9jxz': '25'},
#  {'accident_number': '20200677095',
#   'date_and_time': '2020-10-28T16:38:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '256386',
#   'collision_type': '2',
#   'collision_type_description': 'HEAD-ON',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'EDMONDSON PKE & EDMONDSON PIKE',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37211',
#   'rpa': '8651',
#   'precinct': 'MIDTOW',
#   'lat': '36.0134',
#   'long': '-86.7385',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7385, 36.0134]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '5',
#   ':@computed_region_gxvr_9jxz': '31'},
#  {'accident_number': '20200677074',
#   'date_and_time': '2020-10-28T16:03:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '384436',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'BELL RD & I24 E EXT RAMP',
#   'city': 'ANTIOCH',
#   'state': 'TN',
#   'zip': '37013',
#   'rpa': '8751',
#   'precinct': 'SOUTH',
#   'lat': '36.0451',
#   'long': '-86.6593',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6593, 36.0451]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '30',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'accident_number': '20200677066',
#   'date_and_time': '2020-10-28T16:24:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '306708',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '98',
#   'illumination_description': 'OTHER',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'BELL RD & ELM HILL PKE',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37214',
#   'rpa': '8995',
#   'precinct': 'HERMIT',
#   'lat': '36.1411',
#   'long': '-86.628',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.628, 36.1411]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '6',
#   ':@computed_region_gxvr_9jxz': '38'},
#  {'accident_number': '20200677044',
#   'date_and_time': '2020-10-28T16:11:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '320585',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '36',
#   'harmfuldescriptions': 'CONCRETE TRAFFIC BARRIER',
#   'street_address': 'I24E & I24 W ENT RAMP',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37210',
#   'rpa': '82061',
#   'precinct': 'HERMIT',
#   'lat': '36.1386',
#   'long': '-86.7273',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7273, 36.1386]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '11'},
#  {'accident_number': '20200677024',
#   'date_and_time': '2020-10-28T16:01:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '311333',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '24',
#   'harmfuldescriptions': 'GUARDRAIL FACE',
#   'street_address': 'MM 86 3 I 65',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37207',
#   'rpa': '1910',
#   'precinct': 'CENTRA',
#   'lat': '36.1919',
#   'long': '-86.7808',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7808, 36.1919]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '2',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'accident_number': '20200677009',
#   'date_and_time': '2020-10-28T15:40:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '384449',
#   'collision_type': '6',
#   'collision_type_description': 'SIDESWIPE - OPPOSITE DIRECTION',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'ARBOR COMMON & BEECHWOOD TER',
#   'city': 'ANTIOCH',
#   'state': 'TN',
#   'zip': '37013',
#   'rpa': '8753',
#   'precinct': 'SOUTH',
#   'lat': '36.0449',
#   'long': '-86.6684',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6684, 36.0449]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '29',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'accident_number': '20200676990',
#   'date_and_time': '2020-10-28T15:38:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '212343',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MM 48 9 I 24',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37213',
#   'rpa': '1104',
#   'precinct': 'CENTRA',
#   'lat': '36.1676',
#   'long': '-86.7656',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7656, 36.1676]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '14',
#   ':@computed_region_gxvr_9jxz': '19'},
#  {'accident_number': '20200676983',
#   'date_and_time': '2020-10-28T15:21:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '163667',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '36',
#   'harmfuldescriptions': 'CONCRETE TRAFFIC BARRIER',
#   'street_address': 'MM 78 0 I 65',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37204',
#   'rpa': '8502',
#   'precinct': 'MIDTOW',
#   'lat': '36.0856',
#   'long': '-86.7632',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7632, 36.0856]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '11',
#   ':@computed_region_gxvr_9jxz': '25'},
#  {'accident_number': '20200676982',
#   'date_and_time': '2020-10-28T14:58:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '4001097',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'BLACKMAN RD & WHISPERING HILLS DR',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37211',
#   'rpa': '8609',
#   'precinct': 'MIDTOW',
#   'lat': '36.0721',
#   'long': '-86.7329',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7329, 36.0721]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '21',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'accident_number': '20200676976',
#   'date_and_time': '2020-10-28T00:00:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '2',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '197056',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MURFREESBORO PKE & FAIRCLOTH LN',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37217',
#   'rpa': '8947',
#   'precinct': 'HERMIT',
#   'lat': '36.1032',
#   'long': '-86.6665',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6665, 36.1032]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '22',
#   ':@computed_region_gxvr_9jxz': '22'},
#  {'accident_number': '20200676975',
#   'date_and_time': '2020-10-28T14:15:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '352172',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'HILLSBORO PKE & GREEN HILLS VILLAGE DR',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37215',
#   'rpa': '6411',
#   'precinct': 'MIDTOW',
#   'lat': '36.107',
#   'long': '-86.8132',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8132, 36.107]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '11',
#   ':@computed_region_gxvr_9jxz': '47'},
#  {'accident_number': '20200676972',
#   'date_and_time': '2020-10-28T15:20:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '330411',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'NOLENSVILLE PKE & HARDING PL',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37211',
#   'rpa': '8445',
#   'precinct': 'SOUTH',
#   'lat': '36.0809',
#   'long': '-86.7267',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7267, 36.0809]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '12',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'accident_number': '20200676941',
#   'date_and_time': '2020-10-28T15:14:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '320599',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'RURAL HILL RD & BELL RD',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37217',
#   'rpa': '8939',
#   'precinct': 'HERMIT',
#   'lat': '36.0775',
#   'long': '-86.6218',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6218, 36.0775]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '23',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'accident_number': '20200676933',
#   'date_and_time': '2020-10-28T00:00:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '384448',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MM 54 0 I 24',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37211',
#   'rpa': '88122',
#   'precinct': 'SOUTH',
#   'lat': '36.1064',
#   'long': '-86.7188',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7188, 36.1064]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '9',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'accident_number': '20200676916',
#   'date_and_time': '2020-10-28T15:07:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '2',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '330436',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '42;63',
#   'harmfuldescriptions': 'TREE;Ran Off Road-Right',
#   'street_address': 'UNIVERSITY CT & 1ST AVS',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37210',
#   'rpa': '8201',
#   'precinct': 'HERMIT',
#   'lat': '36.1505',
#   'long': '-86.7656',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7656, 36.1505]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '11'},
#  {'accident_number': '20200676914',
#   'date_and_time': '2020-10-28T15:03:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '409188',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '24;63',
#   'harmfuldescriptions': 'GUARDRAIL FACE;Ran Off Road-Right',
#   'street_address': 'MM 86 2 I 65',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37207',
#   'rpa': '1910',
#   'precinct': 'CENTRA',
#   'lat': '36.1919',
#   'long': '-86.7812',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7812, 36.1919]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '2',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'accident_number': '20200676909',
#   'date_and_time': '2020-10-28T14:55:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '320582',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MM 87 0 I 65',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37207',
#   'rpa': '18020',
#   'precinct': 'EAST',
#   'lat': '36.2018',
#   'long': '-86.7766',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7766, 36.2018]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '13',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'accident_number': '20200676905',
#   'date_and_time': '2020-10-28T14:01:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '384436',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'I24 E ENT RAMP & I 24',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37213',
#   'rpa': '1007',
#   'precinct': 'CENTRA',
#   'lat': '36.1662',
#   'long': '-86.7659',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7659, 36.1662]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '14',
#   ':@computed_region_gxvr_9jxz': '19'},
#  {'accident_number': '20200676881',
#   'date_and_time': '2020-10-28T14:35:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '330435',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'BELL RD & BROOK VIEW ESTATES DR',
#   'city': 'ANTIOCH',
#   'state': 'TN',
#   'zip': '37013',
#   'rpa': '8755',
#   'precinct': 'SOUTH',
#   'lat': '36.0439',
#   'long': '-86.6933',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6933, 36.0439]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '29',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'accident_number': '20200676867',
#   'date_and_time': '2020-10-28T14:35:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '279213',
#   'collision_type': '5',
#   'collision_type_description': 'SIDESWIPE - SAME DIRECTION',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'HILLSBORO PKE & ENCLAVE AT HILLSBORO VIL',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37212',
#   'rpa': '6507',
#   'precinct': 'MIDTOW',
#   'lat': '36.1253',
#   'long': '-86.8056',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8056, 36.1253]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '19',
#   ':@computed_region_gxvr_9jxz': '36'},
#  {'accident_number': '20200676865',
#   'date_and_time': '2020-10-28T13:50:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '419972',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '36',
#   'harmfuldescriptions': 'CONCRETE TRAFFIC BARRIER',
#   'street_address': 'MM 204 6 I 40',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37209',
#   'rpa': '52023',
#   'precinct': 'WEST',
#   'lat': '36.1537',
#   'long': '-86.8452',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8452, 36.1537]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '24',
#   ':@computed_region_gxvr_9jxz': '46'},
#  {'accident_number': '20200676860',
#   'date_and_time': '2020-10-28T14:30:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '320577',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '36',
#   'harmfuldescriptions': 'CONCRETE TRAFFIC BARRIER',
#   'street_address': 'I40 E EXT RAMP & I 40',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37214',
#   'rpa': '8955',
#   'precinct': 'HERMIT',
#   'lat': '36.155',
#   'long': '-86.6271',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6271, 36.155]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '6',
#   ':@computed_region_gxvr_9jxz': '38'},
#  {'accident_number': '20200676842',
#   'date_and_time': '2020-10-28T14:23:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '140790',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MURFREESBORO PKE & RANSOM WAY',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37217',
#   'rpa': '8935',
#   'precinct': 'HERMIT',
#   'lat': '36.091',
#   'long': '-86.6511',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6511, 36.091]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '23',
#   ':@computed_region_gxvr_9jxz': '22'},
#  {'accident_number': '20200676784',
#   'date_and_time': '2020-10-28T13:45:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '4001080',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'weather': '5',
#   'weather_description': 'FOG',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'ANDERSON LN & MCARTHUR DR',
#   'city': 'MADISON',
#   'state': 'TN',
#   'zip': '37115',
#   'rpa': '1715',
#   'precinct': 'MADISO',
#   'lat': '36.2722',
#   'long': '-86.6907',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6907, 36.2722]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '4',
#   ':@computed_region_gxvr_9jxz': '12'},
#  {'accident_number': '20200676777',
#   'date_and_time': '2020-10-28T13:39:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '4001053',
#   'collision_type': '6',
#   'collision_type_description': 'SIDESWIPE - OPPOSITE DIRECTION',
#   'illuaccidemination': '1',
#   'illumination_description': 'DAYLIGHT',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'JOYCE LN & GRINSTEAD PL',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37216',
#   'rpa': '1801',
#   'precinct': 'EAST',
#   'lat': '36.2338',
#   'long': '-86.729',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.729, 36.2338]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '3',
#   ':@computed_region_gxvr_9jxz': '23'},
#  {'accident_number': '20200676776',
#   'date_and_time': '2020-10-26T18:20:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '384403',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'illuaccidemination': '9',
#   'illumination_description': 'UNKNOWN',
#   'harmfulcodes': '14;55',
# ...
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '2',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'accident_number': '20200643660',
#   'date_and_time': '2020-10-10T00:00:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '468098',
#   'collision_type': '9',
#   'collision_type_description': 'UNKNOWN',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '99',
#   'harmfuldescriptions': 'UNKNOWN MOST HARMFUL EVENT',
#   'street_address': 'BELL RD & HICKORY PARK DR',
#   'city': 'ANTIOCH',
#   'state': 'TN',
#   'zip': '37013',
#   'rpa': '8753',
#   'precinct': 'SOUTH',
#   'lat': '36.0449',
#   'long': '-86.6704',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6704, 36.0449]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '29',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'accident_number': '20200643645',
#   'date_and_time': '2020-10-11T04:33:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '311336',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '30',
#   'harmfuldescriptions': 'UTILITY POLE',
#   'street_address': 'MM 49 0 I 24',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37206',
#   'rpa': '10040',
#   'precinct': 'EAST',
#   'lat': '36.1664',
#   'long': '-86.7647',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7647, 36.1664]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '14',
#   ':@computed_region_gxvr_9jxz': '4'},
#  {'accident_number': '20200643603',
#   'date_and_time': '2020-10-11T03:40:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '279216',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12;24',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT;GUARDRAIL FACE',
#   'street_address': 'MM 86 4 I 65',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37207',
#   'rpa': '19060',
#   'precinct': 'EAST',
#   'lat': '36.1937',
#   'long': '-86.7758',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7758, 36.1937]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '2',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'accident_number': '20200643566',
#   'date_and_time': '2020-10-11T03:14:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '384439',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'NOLENSVILLE PKE & HAYWOOD LN',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37211',
#   'rpa': '8661',
#   'precinct': 'MIDTOW',
#   'lat': '36.0683',
#   'long': '-86.7193',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7193, 36.0683]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '21',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'accident_number': '20200643555',
#   'date_and_time': '2020-10-11T03:05:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'property_damage': True,
#   'hit_and_run': False,
#   'reporting_officer': '173951',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '39',
#   'harmfuldescriptions': 'WALL',
#   'street_address': 'GALLATIN PKES & LAKEWOOD DR',
#   'city': 'MADISON',
#   'state': 'TN',
#   'zip': '37115',
#   'rpa': '1517',
#   'precinct': 'MADISO',
#   'lat': '36.2434',
#   'long': '-86.7229',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7229, 36.2434]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '15',
#   ':@computed_region_gxvr_9jxz': '12'},
#  {'accident_number': '20200643540',
#   'date_and_time': '2020-10-11T02:48:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '352170',
#   'collision_type': '5',
#   'collision_type_description': 'SIDESWIPE - SAME DIRECTION',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '2',
#   'illumination_description': 'DARK - NOT LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'US HWY 31 ALT & HAYWOOD LN',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37211',
#   'rpa': '8661',
#   'precinct': 'MIDTOW',
#   'lat': '36.0681',
#   'long': '-86.719',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.719, 36.0681]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '28',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'accident_number': '20200643539',
#   'date_and_time': '2020-10-11T00:00:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '299247',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12;36',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT;CONCRETE TRAFFIC BARRIER',
#   'street_address': 'MM 213 8 I 40',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37217',
#   'rpa': '8802',
#   'precinct': 'HERMIT',
#   'lat': '36.1413',
#   'long': '-86.7163',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7163, 36.1413]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '8',
#   ':@computed_region_gxvr_9jxz': '11'},
#  {'accident_number': '20200643527',
#   'date_and_time': '2020-10-11T02:20:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '200534',
#   'collision_type': '5',
#   'collision_type_description': 'SIDESWIPE - SAME DIRECTION',
#   'illuaccidemination': '2',
#   'illumination_description': 'DARK - NOT LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'MM 80 5 I 65',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37204',
#   'rpa': '69020',
#   'precinct': 'MIDTOW',
#   'lat': '36.1226',
#   'long': '-86.7733',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7733, 36.1226]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '18',
#   ':@computed_region_gxvr_9jxz': '25'},
#  {'accident_number': '20200643521',
#   'date_and_time': '2020-10-11T02:30:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '352193',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '17',
#   'harmfuldescriptions': 'BOULDER',
#   'street_address': 'MM 51 4 I 24',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37210',
#   'rpa': '82061',
#   'precinct': 'HERMIT',
#   'lat': '36.1388',
#   'long': '-86.7284',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7284, 36.1388]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '20',
#   ':@computed_region_gxvr_9jxz': '11'},
#  {'accident_number': '20200643520',
#   'date_and_time': '2020-10-11T02:10:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'property_damage': True,
#   'hit_and_run': False,
#   'reporting_officer': '330440',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '2',
#   'illumination_description': 'DARK - NOT LIGHTED',
#   'harmfulcodes': '41',
#   'harmfuldescriptions': 'SHRUBBERY',
#   'street_address': 'PETTUS RD & PRESTON RD',
#   'city': 'ANTIOCH',
#   'state': 'TN',
#   'zip': '37013',
#   'rpa': '8753',
#   'precinct': 'SOUTH',
#   'lat': '36.0285',
#   'long': '-86.6669',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6669, 36.0285]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '30',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'accident_number': '20200643507',
#   'date_and_time': '2020-10-11T00:00:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': True,
#   'reporting_officer': '279216',
#   'collision_type': '5',
#   'collision_type_description': 'SIDESWIPE - SAME DIRECTION',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12;24',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT;GUARDRAIL FACE',
#   'street_address': 'MM 86 3 I 65',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37207',
#   'rpa': '1910',
#   'precinct': 'CENTRA',
#   'lat': '36.1919',
#   'long': '-86.7808',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7808, 36.1919]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '2',
#   ':@computed_region_gxvr_9jxz': '16'},
#  {'accident_number': '20200643478',
#   'date_and_time': '2020-10-11T01:48:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '4001100',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'OLD HICKORY BLVD & EULALA DR',
#   'city': 'ANTIOCH',
#   'state': 'TN',
#   'zip': '37013',
#   'rpa': '8757',
#   'precinct': 'SOUTH',
#   'lat': '36.0454',
#   'long': '-86.7036',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7036, 36.0454]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '29',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'accident_number': '20200643476',
#   'date_and_time': '2020-10-11T01:27:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '1',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '468098',
#   'collision_type': '11',
#   'collision_type_description': 'Front to Rear',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12;14',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT;PARKED MOTOR VEHICLE',
#   'street_address': 'FAULKNER DR & WILLOW LN',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37211',
#   'rpa': '8703',
#   'precinct': 'SOUTH',
#   'lat': '36.0782',
#   'long': '-86.7115',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.7115, 36.0782]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '28',
#   ':@computed_region_gxvr_9jxz': '3'},
#  {'accident_number': '20200643472',
#   'date_and_time': '2020-10-11T01:35:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'property_damage': True,
#   'hit_and_run': True,
#   'reporting_officer': '352184',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '2',
#   'illumination_description': 'DARK - NOT LIGHTED',
#   'harmfulcodes': '24',
#   'harmfuldescriptions': 'GUARDRAIL FACE',
#   'street_address': 'MT VIEW RD & HICKORY HOLLOW PKWY',
#   'city': 'ANTIOCH',
#   'state': 'TN',
#   'zip': '37013',
#   'rpa': '8859',
#   'precinct': 'SOUTH',
#   'lat': '36.0588',
#   'long': '-86.6705',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6705, 36.0588]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '30',
#   ':@computed_region_gxvr_9jxz': '15'},
#  {'accident_number': '20200643443',
#   'date_and_time': '2020-10-11T01:20:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '2',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '299270',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '12',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT',
#   'street_address': 'ED TEMPLE BLVD & ROSA L PARKS BLVD',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37228',
#   'rpa': '4483',
#   'precinct': 'NORTH',
#   'lat': '36.188',
#   'long': '-86.8216',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8216, 36.188]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '25',
#   ':@computed_region_gxvr_9jxz': '51'},
#  {'accident_number': '20200643431',
#   'date_and_time': '2020-10-11T01:05:00.000',
#   'number_of_motor_vehicles': '1',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '372814',
#   'collision_type': '0',
#   'collision_type_description': 'NOT COLLISION W/MOTOR VEHICLE-TRANSPORT',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '2',
#   'illumination_description': 'DARK - NOT LIGHTED',
#   'harmfulcodes': '30',
#   'harmfuldescriptions': 'UTILITY POLE',
#   'street_address': 'STATE HWY 45 & GOLF CLUB RD',
#   'city': 'OLD HICKORY',
#   'state': 'TN',
#   'zip': '37138',
#   'rpa': '9709',
#   'precinct': 'HERMIT',
#   'lat': '36.2516',
#   'long': '-86.6465',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.6465, 36.2516]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '2',
#   ':@computed_region_p6sk_2acq': '27',
#   ':@computed_region_gxvr_9jxz': '26'},
#  {'accident_number': '20200643421',
#   'date_and_time': '2020-10-10T21:23:00.000',
#   'number_of_motor_vehicles': '2',
#   'number_of_injuries': '0',
#   'number_of_fatalities': '0',
#   'hit_and_run': False,
#   'reporting_officer': '384409',
#   'collision_type': '4',
#   'collision_type_description': 'ANGLE',
#   'weather': '2',
#   'weather_description': 'RAIN',
#   'illuaccidemination': '3',
#   'illumination_description': 'DARK - LIGHTED',
#   'harmfulcodes': '13',
#   'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT-OTHER ROADWAY',
#   'street_address': 'CHARLOTTE PKE & RUSSLEO DR',
#   'city': 'NASHVILLE',
#   'state': 'TN',
#   'zip': '37209',
#   'rpa': '5021',
#   'precinct': 'WEST',
#   'lat': '36.1401',
#   'long': '-86.8793',
#   'mapped_location': {'type': 'Point', 'coordinates': [-86.8793, 36.1401]},
#   ':@computed_region_wvby_4s8j': '1',
#   ':@computed_region_3aw5_2wv7': '1',
#   ':@computed_region_p6sk_2acq': '24',
#   ':@computed_region_gxvr_9jxz': '46'}]

# %%
type(response.json())
# Out:
# list

# %%
response.json()[0]
# Out:
# {'accident_number': 'VU 130097461',
#  'date_and_time': '2013-08-13T00:00:00.000',
#  'number_of_motor_vehicles': '2',
#  'number_of_injuries': '0',
#  'number_of_fatalities': '0',
#  'hit_and_run': True,
#  'reporting_officer': '494',
#  'collision_type': '3',
#  'weather': '1',
#  'weather_description': 'NO ADVERSE CONDITIONS',
#  'illuaccidemination': '1',
#  'illumination_description': 'DAYLIGHT',
#  'harmfulcodes': '12;14',
#  'harmfuldescriptions': 'MOTOR VEHICLE IN TRANSPORT;PARKED MOTOR VEHICLE',
#  'street_address': 'POWELL AVE',
#  'city': 'NASHVILLE',
#  'state': 'TN',
#  'zip': '37204',
#  'rpa': '8525',
#  'precinct': 'MIDTOW',
#  'lat': '36.1099',
#  'long': '-86.7644',
#  'mapped_location': {'type': 'Point', 'coordinates': [-86.7644, 36.1099]},
#  ':@computed_region_wvby_4s8j': '1',
#  ':@computed_region_3aw5_2wv7': '1',
#  ':@computed_region_p6sk_2acq': '9',
#  ':@computed_region_gxvr_9jxz': '25'}

# %%
type(response.json()[0])
# Out:
# dict

# %% [markdown]
# If we want to convert it into a DataFrame, we can use the text of the response since `read_json` can accept a string formatted as json.

# %%
crashes = pd.read_json(response.text)

# %%
crashes.head()
# Out:
#   accident_number       date_and_time  number_of_motor_vehicles  \
# 0    VU 130097461 2013-08-13 00:00:00                         2
# 1     20400639785 2014-07-06 12:45:00                         2
# 2     20200677519 2020-10-28 19:35:00                         2
# 3     20200677514 2020-10-28 21:15:00                         2
# 4     20200677469 2020-10-28 20:30:00                         2
#
#    number_of_injuries  number_of_fatalities  hit_and_run  reporting_officer  \
# 0                   0                     0         True                494
# 1                   0                     0        False             473187
# 2                   0                     0         True             352172
# 3                   0                     0        False            4001081
# 4                   0                     0        False             320586
#
#    collision_type  weather    weather_description  ...  precinct      lat  \
# 0               3      1.0  NO ADVERSE CONDITIONS  ...    MIDTOW  36.1099
# 1               5     21.0                  CLEAR  ...    MADISO   0.0000
# 2               4      NaN                    NaN  ...      WEST  36.1264
# 3               5      NaN                    NaN  ...    MADISO  36.2435
# 4               6      NaN                    NaN  ...    HERMIT  36.1713
#
#       long                                    mapped_location  \
# 0 -86.7644  {'type': 'Point', 'coordinates': [-86.7644, 36...
# 1   0.0000           {'type': 'Point', 'coordinates': [0, 0]}
# 2 -86.8456  {'type': 'Point', 'coordinates': [-86.8456, 36...
# 3 -86.7481  {'type': 'Point', 'coordinates': [-86.7481, 36...
# 4 -86.6555  {'type': 'Point', 'coordinates': [-86.6555, 36...
#
#   :@computed_region_wvby_4s8j :@computed_region_3aw5_2wv7  \
# 0                         1.0                         1.0
# 1                         NaN                         NaN
# 2                         1.0                         1.0
# 3                         1.0                         1.0
# 4                         1.0                         1.0
#
#   :@computed_region_p6sk_2acq  :@computed_region_gxvr_9jxz  \
# 0                         9.0                         25.0
# 1                         NaN                          NaN
# 2                        10.0                          5.0
# 3                         3.0                         12.0
# 4                         7.0                         38.0
#
#        collision_type_description property_damage
# 0                             NaN             NaN
# 1      SIDESWIPE - SAME DIRECTION             NaN
# 2                           ANGLE             NaN
# 3      SIDESWIPE - SAME DIRECTION             NaN
# 4  SIDESWIPE - OPPOSITE DIRECTION             NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# If we have a DataFrame we with to export to a json file, we can use the `to_json` method.

# %%
crashes.to_json('data/crashes.json')

# %% [markdown]
# If you inspect the resulting file, it does not look like the response text from above. This is because it is in "columns" orientation. To make it look like the response text, we need to output using "records" orientation.

# %%
crashes.to_json('data/crashes_records.json', orient = 'records')

# %% [markdown]
# Notice that `json.load()` will read in a JSON file into an object of type depending on the format of the JSON file.

# %%
with open('data/crashes_records.json', 'r') as fi:
    crashes_from_json = json.load(fi)

# %%
type(crashes_from_json)
# Out:
# list
